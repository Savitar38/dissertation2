# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

pd.options.display.max_colwidth = 200
pd.options.display.max_rows = 205
pd.set_option('display.max_columns', None)

# %%
party = pd.read_excel("./datasets/parlgov/parlgov-stable.xlsx", sheet_name="party")
election = pd.read_excel("./datasets/parlgov/parlgov-stable.xlsx", sheet_name="election")
cabinet = pd.read_excel("./datasets/parlgov/parlgov-stable.xlsx", sheet_name="cabinet")

# %%
party.head()
# Out:
#   country_name_short country_name party_name_short  \
# 0                AUS    Australia            ACP-V
# 1                AUS    Australia               AD
# 2                AUS    Australia               AG
# 3                AUS    Australia              ALP
# 4                AUS    Australia               AP
#
#                party_name_english                      party_name  \
# 0  Australian Country Party (Vic)  Australian Country Party (Vic)
# 1            Australian Democrats            Australian Democrats
# 2               Australian Greens               Australian Greens
# 3          Australian Labor Party          Australian Labor Party
# 4                 Australia Party                 Australia Party
#
#                  party_name_ascii family_name_short       family_name  \
# 0  Australian Country Party (Vic)               con      Conservative
# 1            Australian Democrats               soc  Social democracy
# ...

# %%
election.head()
# Out:
#   country_name_short country_name election_type election_date  vote_share  \
# 0                AUS    Australia    parliament    1901-03-30        44.4
# 1                AUS    Australia    parliament    1901-03-30        34.2
# 2                AUS    Australia    parliament    1901-03-30        19.4
# 3                AUS    Australia    parliament    1901-03-30         1.4
# 4                AUS    Australia    parliament    1901-03-30         0.6
#
#    seats  seats_total party_name_short              party_name  \
# 0   32.0           75               PP     Protectionist Party
# 1   26.0           75              FTP        Free Trade Party
# 2   15.0           75              ALP  Australian Labor Party
# 3    1.0           75             none    no party affiliation
# 4    1.0           75         one-seat                one seat
#
#        party_name_english  left_right  country_id  election_id  \
# 0     Protectionist Party      7.4000          33          731
# ...

# %%
cabinet.head()
# Out:
#   country_name_short country_name election_date  start_date cabinet_name  \
# 0                AUS    Australia    1901-03-30  1901-03-30       Barton
# 1                AUS    Australia    1901-03-30  1901-03-30       Barton
# 2                AUS    Australia    1901-03-30  1901-03-30       Barton
# 3                AUS    Australia    1901-03-30  1901-03-30       Barton
# 4                AUS    Australia    1901-03-30  1901-03-30       Barton
#
#    caretaker  cabinet_party  prime_minister  seats  election_seats_total  \
# 0          1              0               0     15                    75
# 1          1              0               0     26                    75
# 2          1              1               1     32                    75
# 3          1              0               0      1                    75
# 4          1              0               0      1                    75
#
#   party_name_short              party_name      party_name_english  \
# ...

# %%
print(party.info(), election.info(), cabinet.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1707 entries, 0 to 1706
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country_name_short  1707 non-null   object
#  1   country_name        1707 non-null   object
#  2   party_name_short    1707 non-null   object
#  3   party_name_english  1707 non-null   object
#  4   party_name          1707 non-null   object
#  5   party_name_ascii    1707 non-null   object
#  6   family_name_short   1707 non-null   object
#  7   family_name         1707 non-null   object
#  8   left_right          1387 non-null   float64
#  9   state_market        1386 non-null   float64
#  10  liberty_authority   1386 non-null   float64
#  11  eu_anti_pro         1103 non-null   float64
#  12  cmp                 490 non-null    float64
#  13  euprofiler          227 non-null    float64
#  14  ees                 207 non-null    float64
# ...

# %%
cabinet["start_date"] = pd.to_datetime(cabinet["start_date"])
cabinet["election_date"] = pd.to_datetime(cabinet["election_date"])

# %%
cabinet = cabinet[(cabinet["start_date"].dt.year >= 2010) & (cabinet["start_date"].dt.year <= 2020)]

# %%
# cabinet = cabinet[cabinet["cabinet_party"] == 1] We want to examine the sentiment so we should include all the parties

# %%
cabinet[cabinet["country_name_short"] == "SVK"]
# Out:
#       country_name_short country_name election_date start_date cabinet_name  \
# 11938                SVK     Slovakia    2010-06-12 2010-07-08   Radicova I
# 11939                SVK     Slovakia    2010-06-12 2010-07-08   Radicova I
# 11942                SVK     Slovakia    2010-06-12 2010-07-08   Radicova I
# 11944                SVK     Slovakia    2010-06-12 2010-07-08   Radicova I
# 11946                SVK     Slovakia    2010-06-12 2011-10-20  Radicova II
# 11947                SVK     Slovakia    2010-06-12 2011-10-20  Radicova II
# 11951                SVK     Slovakia    2010-06-12 2011-10-20  Radicova II
# 11953                SVK     Slovakia    2010-06-12 2011-10-20  Radicova II
# 11961                SVK     Slovakia    2012-03-10 2012-04-04      Fico II
# 11963                SVK     Slovakia    2016-03-06 2016-03-23     Fico III
# 11965                SVK     Slovakia    2016-03-06 2016-03-23     Fico III
# ...
