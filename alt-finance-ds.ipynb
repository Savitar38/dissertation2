# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %% [markdown]
# https://cohesiondata.ec.europa.eu/2014-2020-Categorisation/ESIF-2014-2020-categorisation-ERDF-ESF-CF-planned-/3kkx-ekfq/related_content
#
# (https://cohesiondata.ec.europa.eu/2014-2020/2014-2020-Cohesion-Categorisation-Intervention-fie/t9jb-dvk6/about_data)
#
# https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A32014R0215

# %%
df = pd.read_csv("datasets/esif-14-20.csv")
df
# Out:
#        Member State (2 digit ISO)              CCI  \
# 0                              SK  2014SK16M1OP001
# 1                              CZ  2014CZ05M2OP001
# 2                              GR  2014GR16M1OP001
# 3                              BG  2014BG05M9OP001
# 4                              ES  2014ES16RFOP019
# ...                           ...              ...
# 473338                         GR  2014GR16M2OP004
# 473339                         PL  2014PL16M2OP003
# 473340                         FR  2014FR05M0OP001
# 473341                         DE  2014DE16RFOP015
# 473342                         ES  2014ES16RFOP006
#
#                                           Programme Title  Programme version  \
# 0                Integrated Infrastructure - SK - ERDF/CF                6.0
# 1       Research Development and Education - CZ - ESF/...                3.0
# 2       Transport Infrastructure Environment and Susta...                3.0
# ...

# %%
df.columns
# Out:
# Index(['Member State (2 digit ISO)', 'CCI', 'Programme Title',
#        'Programme version', 'status', 'Priority', 'Pax React EU', 'Pax CARE',
#        'Pax React EU CARE', 'Fund', 'Category of region', 'Year',
#        'Dimension Type', 'Dimension title (short)', 'Dimension code',
#        'Dimension title (long)', 'Financial Data Version',
#        'EU_cofinancing_rate', 'Planned_Total_Amount_(Notional)',
#        'EU_amount_planned', 'Total_Eligible_Costs_Decided_(selected)',
#        'EU_Eligible_Costs_Decided_(selected_notional)',
#        'Public_Eligible_Costs_Fin_data',
#        'Total_spend_(Elig_Expenditure_Declared)',
#        'EU_spend_share_(Elig_Expenditure_Declared_notional)', 'Reference Date',
#        'Planned EU Amount for Climate action',
#        'Decided EU Amount for Climate action (est.)',
#        'Spent EU Amount for Climate action (est.)',
#        'Planned EU Amount for Biodiversity',
#        'Decided EU Amount for Biodiversity (est.)',
# ...
